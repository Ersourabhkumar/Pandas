# %%
# Pandas---> Pandas is an open-source library that is used for data mannipulations.

# %%
#!pip install pandas---> for jupyter notebook 
# pip innstall pandas---> for vs code

# %%
import pandas as pd

# %%
# data structure of Pandas
#(1). Series--> it id 1-D array and it return only values not colomn name.
# (2). Dataframe---> it is multi-dimensional aaray and it returns column name with values

# %%
#Series

# %%
a=pd.Series([1,34,67,90])  #always capitale S
#a

# %%
#type(a)

# %%
#DataFrame

# %%
a={
    "Emp_ID":[1,2,3,4,5],
    "Name":["Sam","Raj","Rahul","Aniket","Pallavi"],
    "Department":["IT","Sales","Sales", "HR","HR"],
    "Working_hours":[8,8,8,9,9],
    "Salary":[20000,25000,34000,31000,28000]
    
}

# %%
df=pd.DataFrame(a)
df
# Out:
#    Emp_ID     Name Department  Working_hours  Salary
# 0       1      Sam         IT              8   20000
# 1       2      Raj      Sales              8   25000
# 2       3    Rahul      Sales              8   34000
# 3       4   Aniket         HR              9   31000
# 4       5  Pallavi         HR              9   28000

# %%
# how can we export this data into csv format?

# %%
df.to_csv("emp_data.csv",index=False)

# %%
#How can we export this data into excel forma?

# %%
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
df.to_excel("update_emp_data.xlsx" , index=False)

# %%
#how do you import excel data?

# %%
a=pd.read_excel("update_emp_data.xlsx")
a
# Out:
#    Emp_ID     Name Department  Working_hours  Salary
# 0       1      Sam         IT              8   20000
# 1       2      Raj      Sales              8   25000
# 2       3    Rahul      Sales              8   34000
# 3       4   Aniket         HR              9   31000
# 4       5  Pallavi         HR              9   28000

# %%
#How do you import csv data?

# %%
a=pd.read_csv("emp_data.csv")
a
# Out:
#    Emp_ID     Name Department  Working_hours  Salary
# 0       1      Sam         IT              8   20000
# 1       2      Raj      Sales              8   25000
# 2       3    Rahul      Sales              8   34000
# 3       4   Aniket         HR              9   31000
# 4       5  Pallavi         HR              9   28000

# %%
df=pd.read_csv("google.csv")
df
# Out:
#                                       Restaurant_name  Rating  \
# 0                                       Suvarna Mahal     4.7
# 1                                  Skyfall Restaurant     4.3
# 2                 J Brew & Kitchen Rooftop Restaurant     4.8
# 3                                                 NaN     NaN
# 4        Brewlicious Rooftop Bar Restaurant in Jaipur     4.8
# 5                                     Stardust Jaipur     4.2
# 6                                  Peacock Restaurant     4.4
# 7                                            The Lama     4.7
# 8   Topaz & Sangria - FineDine, SkyLounge & Skydec...     4.6
# 9                                    Govindam Retreat     4.4
# 10                                     Rosella Jaipur     4.6
# 11        LASA Bistro | Pure Veg Restaurant in Jaipur     4.2
# 12                                       Thali & more     4.4
# 13                                 Monarch Restaurant     4.6
# ...

# %%
hp=pd.read_csv("Hp laptop.csv")
hp
# Out:
#                                            Model_name  Rating       Review  \
# 0   HP 15 Intel Core 3 14th Gen 100U - (8 GB/512 G...     4.1   12 Reviews
# 1   HP Laptop Intel Core i3 12th Gen 1215U - (8 GB...     4.2  372 Reviews
# 2   HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...     4.2  579 Reviews
# 3   HP Intel Celeron Dual Core N4500 - (8 GB/512 G...     5.0    0 Reviews
# 4   HP 15s AMD Ryzen 3 Quad Core 5300U - (8 GB/512...     4.3  476 Reviews
# 5   HP AMD Athlon Dual Core - (8 GB/256 GB SSD/Win...     4.1   71 Reviews
# 6   HP AMD Athlon Dual Core 3050U - (8 GB/512 GB S...     4.0  144 Reviews
# 7   HP G9 SERIES AMD Athlon Dual Core 3050U - (4 G...     4.1    6 Reviews
# 8   HP Intel Core N 12th Gen - (8 GB/512 GB SSD/Wi...     NaN          NaN
# 9   HP 15s Intel Core i5 12th Gen 1240P - (8 GB/51...     4.1   21 Reviews
# 10  HP 255 G9 AMD Athlon Dual Core AMD Athlon Silv...     4.0  131 Reviews
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("userbehaviour - userbehaviour.csv")

# %%
df
# Out:
#      userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0      1001                   17                         634            1
# 1      1002                    0                          54            0
# 2      1003                   37                         207            0
# 3      1004                   32                         445            1
# 4      1005                   45                         427            1
# ..      ...                  ...                         ...          ...
# 994    1995                   38                         938            0
# 995    1996                   43                          61            0
# 996    1997                   47                         761            0
# 997    1998                    6                          73            1
# 998    1999                    9                          54            0
#
#      Ratings  New Password Request  Last Visited Minutes       Status
# ...

# %%
df.head()
# Out:
#    userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0    1001                   17                         634            1
# 1    1002                    0                          54            0
# 2    1003                   37                         207            0
# 3    1004                   32                         445            1
# 4    1005                   45                         427            1
#
#    Ratings  New Password Request  Last Visited Minutes       Status
# 0        9                     7                  2990    Installed
# 1        4                     8                 24008  Uninstalled
# 2        8                     5                   971    Installed
# 3        6                     2                   799    Installed
# 4        5                     6                  3668    Installed

# %%
df.tail()
# Out:
#      userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 994    1995                   38                         938            0
# 995    1996                   43                          61            0
# 996    1997                   47                         761            0
# 997    1998                    6                          73            1
# 998    1999                    9                          54            0
#
#      Ratings  New Password Request  Last Visited Minutes     Status
# 994        5                     4                  1865  Installed
# 995        6                     8                  1327  Installed
# 996        6                     1                  1936  Installed
# 997        5                     1                  3436  Installed
# 998        4                     2                  4039  Installed

# %%
df.info
# Out:
# <bound method DataFrame.info of      userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0      1001                   17                         634            1
# 1      1002                    0                          54            0
# 2      1003                   37                         207            0
# 3      1004                   32                         445            1
# 4      1005                   45                         427            1
# ..      ...                  ...                         ...          ...
# 994    1995                   38                         938            0
# 995    1996                   43                          61            0
# 996    1997                   47                         761            0
# 997    1998                    6                          73            1
# 998    1999                    9                          54            0
#
# ...

# %%
df.describe()
# Out:
#             userid  Average Screen Time  Average Spent on App (INR)  \
# count   999.000000           999.000000                  999.000000
# mean   1500.000000            24.390390                  424.415415
# std     288.530761            14.235415                  312.365695
# min    1001.000000             0.000000                    0.000000
# 25%    1250.500000            12.000000                   96.000000
# 50%    1500.000000            24.000000                  394.000000
# 75%    1749.500000            36.000000                  717.500000
# max    1999.000000            50.000000                  998.000000
#
#        Left Review     Ratings  New Password Request  Last Visited Minutes
# count   999.000000  999.000000            999.000000            999.000000
# mean      0.497497    6.513514              4.941942           5110.898899
# std       0.500244    2.701511              2.784626           8592.036516
# ...

# %%
df.loc[5:8,["userid","Ratings"]]
# Out:
#    userid  Ratings
# 5    1006        9
# 6    1007        9
# 7    1008        2
# 8    1009        8

# %%
df.iloc[5:8,[0,2,5]]
# Out:
#    userid  Average Spent on App (INR)  New Password Request
# 5    1006                         599                     4
# 6    1007                         887                     6
# 7    1008                          31                     1

# %%
df.isnull().sum()
# Out:
# userid                        0
# Average Screen Time           0
# Average Spent on App (INR)    0
# Left Review                   0
# Ratings                       0
# New Password Request          0
# Last Visited Minutes          0
# Status                        0
# dtype: int64

# %%
df.head(7)
# Out:
#    userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0    1001                   17                         634            1
# 1    1002                    0                          54            0
# 2    1003                   37                         207            0
# 3    1004                   32                         445            1
# 4    1005                   45                         427            1
# 5    1006                   28                         599            0
# 6    1007                   49                         887            1
#
#    Ratings  New Password Request  Last Visited Minutes       Status
# 0        9                     7                  2990    Installed
# 1        4                     8                 24008  Uninstalled
# 2        8                     5                   971    Installed
# 3        6                     2                   799    Installed
# ...

# %%
df.dtypes
# Out:
# userid                         int64
# Average Screen Time            int64
# Average Spent on App (INR)     int64
# Left Review                    int64
# Ratings                        int64
# New Password Request           int64
# Last Visited Minutes           int64
# Status                        object
# dtype: object

# %%
df["Ratings"]=df["Ratings"].astype(float)

# %%
df.head()
# Out:
#    userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0    1001                   17                         634            1
# 1    1002                    0                          54            0
# 2    1003                   37                         207            0
# 3    1004                   32                         445            1
# 4    1005                   45                         427            1
#
#    Ratings  New Password Request  Last Visited Minutes       Status
# 0      9.0                     7                  2990    Installed
# 1      4.0                     8                 24008  Uninstalled
# 2      8.0                     5                   971    Installed
# 3      6.0                     2                   799    Installed
# 4      5.0                     6                  3668    Installed

# %%
df.shape
# Out:
# (999, 8)

# %%
df.dropna()
# Out:
#      userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0      1001                   17                         634            1
# 1      1002                    0                          54            0
# 2      1003                   37                         207            0
# 3      1004                   32                         445            1
# 4      1005                   45                         427            1
# ..      ...                  ...                         ...          ...
# 994    1995                   38                         938            0
# 995    1996                   43                          61            0
# 996    1997                   47                         761            0
# 997    1998                    6                          73            1
# 998    1999                    9                          54            0
#
#      Ratings  New Password Request  Last Visited Minutes       Status
# ...

# %%
df.shape #no row and columns are drop
# Out:
# (999, 8)

# %%
df["Average Spent on App (INR)"].add(5)
# Out:
# 0      639
# 1       59
# 2      212
# 3      450
# 4      432
#       ...
# 994    943
# 995     66
# 996    766
# 997     78
# 998     59
# Name: Average Spent on App (INR), Length: 999, dtype: int64

# %%
df[["userid","Ratings"]]
# Out:
#      userid  Ratings
# 0      1001      9.0
# 1      1002      4.0
# 2      1003      8.0
# 3      1004      6.0
# 4      1005      5.0
# ..      ...      ...
# 994    1995      5.0
# 995    1996      6.0
# 996    1997      6.0
# 997    1998      5.0
# 998    1999      4.0
#
# [999 rows x 2 columns]

# %%
df["Status"].value_counts()
# Out:
# Status
# Installed      916
# Uninstalled     83
# Name: count, dtype: int64

# %%
# df["Status"].values

# %%
df.head(6)
# Out:
#    userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0    1001                   17                         634            1
# 1    1002                    0                          54            0
# 2    1003                   37                         207            0
# 3    1004                   32                         445            1
# 4    1005                   45                         427            1
# 5    1006                   28                         599            0
#
#    Ratings  New Password Request  Last Visited Minutes       Status
# 0      9.0                     7                  2990    Installed
# 1      4.0                     8                 24008  Uninstalled
# 2      8.0                     5                   971    Installed
# 3      6.0                     2                   799    Installed
# 4      5.0                     6                  3668    Installed
# ...

# %%
a=df.columns
a=a.to_list()

# %%
a[1]="AST"
a[2]="ASA"

# %%
a
# Out:
# ['userid',
#  'AST',
#  'ASA',
#  'Left Review',
#  'Ratings',
#  'New Password Request',
#  'Last Visited Minutes',
#  'Status']

# %%
new_df=pd.DataFrame(df.values,columns=a)

# %%
new_df
# Out:
#     userid AST  ASA Left Review Ratings New Password Request  \
# 0     1001  17  634           1     9.0                    7
# 1     1002   0   54           0     4.0                    8
# 2     1003  37  207           0     8.0                    5
# 3     1004  32  445           1     6.0                    2
# 4     1005  45  427           1     5.0                    6
# ..     ...  ..  ...         ...     ...                  ...
# 994   1995  38  938           0     5.0                    4
# 995   1996  43   61           0     6.0                    8
# 996   1997  47  761           0     6.0                    1
# 997   1998   6   73           1     5.0                    1
# 998   1999   9   54           0     4.0                    2
#
#     Last Visited Minutes       Status
# 0                   2990    Installed
# 1                  24008  Uninstalled
# 2                    971    Installed
# 3                    799    Installed
# ...

# %%
df
# Out:
#      userid  Average Screen Time  Average Spent on App (INR)  Left Review  \
# 0      1001                   17                         634            1
# 1      1002                    0                          54            0
# 2      1003                   37                         207            0
# 3      1004                   32                         445            1
# 4      1005                   45                         427            1
# ..      ...                  ...                         ...          ...
# 994    1995                   38                         938            0
# 995    1996                   43                          61            0
# 996    1997                   47                         761            0
# 997    1998                    6                          73            1
# 998    1999                    9                          54            0
#
#      Ratings  New Password Request  Last Visited Minutes       Status
# ...

# %%
df=df.rename(columns={"Average Screen Time":"Update_AST","Average Spent on App (INR)":"Update_ASA"})

# %%
df
# Out:
#      userid  Update_AST  Update_ASA  Left Review  Ratings  \
# 0      1001          17         634            1      9.0
# 1      1002           0          54            0      4.0
# 2      1003          37         207            0      8.0
# 3      1004          32         445            1      6.0
# 4      1005          45         427            1      5.0
# ..      ...         ...         ...          ...      ...
# 994    1995          38         938            0      5.0
# 995    1996          43          61            0      6.0
# 996    1997          47         761            0      6.0
# 997    1998           6          73            1      5.0
# 998    1999           9          54            0      4.0
#
#      New Password Request  Last Visited Minutes       Status
# 0                       7                  2990    Installed
# 1                       8                 24008  Uninstalled
# 2                       5                   971    Installed
# ...
